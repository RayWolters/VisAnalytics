# %%
# IMPORTS
from nltk.corpus import stopwords
from nltk import word_tokenize
# from stop_words import get_stop_words

# %%
# READ DATA
path = '../../data/articles/'
##############################PRE-PROCESSING
# GET STOP WORDS
nltk_w = list(stopwords.words('english'))
# READ ARTICLES
documents = [open(path + f, 'r', encoding='latin-1').read() for f in os.listdir(path)]

# TOKENIZE ARTICLES
documents_tokenized = []
for doc in documents:
    documents_tokenized.append(word_tokenize(doc))

# REMOVE STOP WORDS 
documents_wo_stop = []
for doc in documents_tokenized:
    documents_wo_stop.append([word for word in doc if word not in stopwords.words('english')])
            
documents_wo_stop[0]
# Out:
# ['The',
#  'Orb',
#  'BUMP',
#  'OF',
#  'PROTESTS',
#  'IN',
#  'ABILA',
#  'IN',
#  'RESPONSE',
#  'TO',
#  'THE',
#  'CALLS',
#  'TO',
#  'THE',
#  'ACTION',
#  '2012/09/08',
#  'ABILA',
#  ',',
#  'Kronos',
#  '-',
#  'thousands',
#  'people',
#  'striped',
#  'roads',
#  'Thursday',
#  'posting',
#  'solidarity',
#  'anti-government',
#  '.',
#  'Among',
#  'demonstrators',
#  'Mestache',
#  'Vardshvna',
#  ',',
#  '23',
#  ',',
#  'Western',
#  'coast',
#  'Kronos',
#  '.',
#  '``',
#  'We',
#  'try',
#  'obtain',
#  'attention',
#  'government',
#  ',',
#  "''",
#  'said',
#  '.',
#  '``',
#  'It',
#  'important',
#  ',',
#  'thus',
#  'I',
#  'took',
#  'leave',
#  'work',
#  'part',
#  'important',
#  'event',
#  '.',
#  "''",
#  'It',
#  'one',
#  'much',
#  'used',
#  'power',
#  'free',
#  'speech',
#  'express',
#  'concern',
#  'current',
#  'lack',
#  'transparency',
#  'government',
#  'public',
#  'moneys',
#  '.',
#  '``',
#  'They',
#  'must',
#  'realize',
# ...

# %%
# USER - INPUT

# FILTER ON THESE IN ALL ARTICLES

# CREATE VECTORS

# INCREASE WEIGHT OF THESE WORDS

# CALCULATE COSINE SIMILARITY

# GET CLUSTERS USING DIM REDUCTION  e.g. PCA, TSNE, combination of both

# PLOT CLUSTERS
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
# ...
